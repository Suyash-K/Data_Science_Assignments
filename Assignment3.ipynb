# %% [markdown]
# <a href="https://colab.research.google.com/github/Suyash-K/Data_Science_Assignments/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
d1= pd.DataFrame({'RN':[1,2,3,4,5],'SName':['Nishant','Sarvesh','Suyash','Soham','Shubham']})
d2= pd.DataFrame({'RN':[1,2,3,4,5],'Marks':['40','45','49','46','50']})
d3= pd.merge(d1,d2,on='RN')

# %%
d3
# Out:
#    RN    SName Marks
# 0   1  Nishant    40
# 1   2  Sarvesh    45
# 2   3   Suyash    49
# 3   4    Soham    46
# 4   5  Shubham    50

# %%
df= pd.DataFrame({'RN':[1,2,3,4,5],'SName':['Nishant','Sarvesh','Suyash','Soham','Shubham'],'Marks':['40','45','49','46','50']})

# %%
df.pivot(index='RN',columns='SName',values='Marks')
# Out:
# SName Nishant Sarvesh Shubham Soham Suyash
# RN
# 1          40     NaN     NaN   NaN    NaN
# 2         NaN      45     NaN   NaN    NaN
# 3         NaN     NaN     NaN   NaN     49
# 4         NaN     NaN     NaN    46    NaN
# 5         NaN     NaN      50   NaN    NaN

# %%
df1= pd.DataFrame({'RN':[1,2,None,4,None],'SName':['Nishant','Sarvesh','Suyash','Soham','Shubham'],'Marks':['40','45','49','46','50']})

# %%
df3=df1.pivot(index='RN',columns='SName',values='Marks')

# %%
df1
# Out:
#     RN    SName Marks
# 0  1.0  Nishant    40
# 1  2.0  Sarvesh    45
# 2  NaN   Suyash    49
# 3  4.0    Soham    46
# 4  NaN  Shubham    50

# %%
df1.bfill(axis=0)
# Out:
#     RN    SName Marks
# 0  1.0  Nishant    40
# 1  2.0  Sarvesh    45
# 2  4.0   Suyash    49
# 3  4.0    Soham    46
# 4  NaN  Shubham    50

# %%
df1.ffill(axis=0)
# Out:
#     RN    SName Marks
# 0  1.0  Nishant    40
# 1  2.0  Sarvesh    45
# 2  2.0   Suyash    49
# 3  4.0    Soham    46
# 4  4.0  Shubham    50

# %%
df2=df1.bfill(axis=1)
df2
# Out:
#         RN    SName Marks
# 0      1.0  Nishant    40
# 1      2.0  Sarvesh    45
# 2   Suyash   Suyash    49
# 3      4.0    Soham    46
# 4  Shubham  Shubham    50

# %%
data=pd.read_excel('/content/Demo Data DSBDA (1).xlsx')
data
# Out:
#           Sr. no.                    Roll No        Name of the Student   DM  \
# 0               1                     SCOA01              ALISHA SHEIKH   24
# 1               2                     SCOA02  SOHAM JAYYANNTH DESHMUKKH   16
# 2               3                     SCOA03         SHELAR NEHA NILESH   20
# 3               4                     SCOA04                RIYA JAWALE   18
# 4               5                     SCOA05      NARHE VARSHA RAOSAHEB   20
# ..            ...                        ...                        ...  ...
# 77  Maximum marks                        NaN                        NaN   24
# 78            NaN                        NaN                        NaN  NaN
# 79            NaN                        NaN                        NaN  NaN
# 80            NaN                        NaN                        NaN  NaN
# 81            NaN  Internal Exam Coordinator                        NaN  NaN
#
# ...

# %%
genders = ['Male', 'Female']
data['Gender'] = np.random.choice(genders, size=len(data))

# %%
data
# Out:
#           Sr. no.                    Roll No        Name of the Student   DM  \
# 0               1                     SCOA01              ALISHA SHEIKH   24
# 1               2                     SCOA02  SOHAM JAYYANNTH DESHMUKKH   16
# 2               3                     SCOA03         SHELAR NEHA NILESH   20
# 3               4                     SCOA04                RIYA JAWALE   18
# 4               5                     SCOA05      NARHE VARSHA RAOSAHEB   20
# ..            ...                        ...                        ...  ...
# 77  Maximum marks                        NaN                        NaN   24
# 78            NaN                        NaN                        NaN  NaN
# 79            NaN                        NaN                        NaN  NaN
# 80            NaN                        NaN                        NaN  NaN
# 81            NaN  Internal Exam Coordinator                        NaN  NaN
#
# ...

# %%
d=data.groupby('Gender')
d.first()
# Out:
#        Sr. no.  Roll No Name of the Student  DM FDS OOP  CG DELD  Unnamed: 8  \
# Gender
# Female       1   SCOA01       ALISHA SHEIKH  24  27  20  15   16         NaN
# Male         3   SCOA03  SHELAR NEHA NILESH  20  23  16  15   15         NaN
#
#         Unnamed: 9  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# Gender              ...
# Female         NaN  ...          NaN          NaN          NaN          NaN
# Male           NaN  ...          NaN          NaN          NaN          NaN
#
#         Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# Gender
# Female          NaN          NaN          NaN          NaN          NaN
# Male            NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 23
# Gender
# Female            `
# Male           321`
#
# [2 rows x 24 columns]

# %%
d.count()
# Out:
#         Sr. no.   Roll No  Name of the Student  DM  FDS  OOP  CG  DELD  \
# Gender
# Female       41        38                   38  41   41   41  41    41
# Male         35        30                   29  35   35   35  36    35
#
#         Unnamed: 8  Unnamed: 9  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# Gender                          ...
# Female           0           0  ...            0            0            0
# Male             0           0  ...            0            0            0
#
#         Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# Gender
# Female            0            0            0            0            0
# Male              0            0            0            0            0
#
#         Unnamed: 22  Unnamed: 23
# Gender
# Female            0            1
# Male              0            1
#
# [2 rows x 24 columns]

# %%
d.size()
# Out:
# Gender
# Female    44
# Male      38
# dtype: int64

# %%
print(d.get_group('Male'))
# Out:
#                           Sr. no.                    Roll No  \
# 2                               3                     SCOA03
# 3                               4                     SCOA04
# 4                               5                     SCOA05
# 5                               6                     SCOA06
# 6                               7                     SCOA07
# 8                               9                     SCOA09
# 10                             11                     SCOA11
# 11                             12                     SCOA12
# 13                             14                     SCOA14
# 17                             18                     SCOA18
# 21                             22                     SCOA22
# 24                             25                     SCOA25
# 27                             28                     SCOA28
# 28                             29                     SCOA29
# ...

# %%
data['DM'] = pd.to_numeric(data['DM'], errors='coerce')
data['DELD'] = pd.to_numeric(data['DELD'], errors='coerce')
data['DM'].corr(data['DELD'])
# Out:
# 0.786340702410276

# %%
data=data.iloc[:67]
data
# Out:
#    Sr. no.  Roll No        Name of the Student    DM FDS OOP  CG  DELD  \
# 0        1   SCOA01              ALISHA SHEIKH  24.0  27  20  15  16.0
# 1        2   SCOA02  SOHAM JAYYANNTH DESHMUKKH  16.0   9   9  AB   NaN
# 2        3   SCOA03         SHELAR NEHA NILESH  20.0  23  16  15  15.0
# 3        4   SCOA04                RIYA JAWALE  18.0  14  11   8  15.0
# 4        5   SCOA05      NARHE VARSHA RAOSAHEB  20.0  24  16  24  20.0
# ..     ...      ...                        ...   ...  ..  ..  ..   ...
# 62      63   SCOA64     SHINDE HARSH PRABHAKAR  10.0  17   2   9   8.0
# 63      64   SCOA65             HARSH V KAMBLE  10.0  17   8   5   9.0
# 64      65   SCOA66        DESHMUKH YASH ANANT   4.0  15   3   4   1.0
# 65      66   SCOA67     PATIL DHRUVRAJ VINAYAK   1.0   2   2  AB   NaN
# 66      67   SCOA68      KUNWAR ABHIJEET SINGH  10.0  14   7  18   NaN
#
#     Unnamed: 8  Unnamed: 9  ...  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# ...

# %%
new_data=data[['Sr. no.','DM','FDS','OOP','CG','DELD']]
new_data
# Out:
#    Sr. no.    DM FDS OOP  CG  DELD
# 0        1  24.0  27  20  15  16.0
# 1        2  16.0   9   9  AB   NaN
# 2        3  20.0  23  16  15  15.0
# 3        4  18.0  14  11   8  15.0
# 4        5  20.0  24  16  24  20.0
# ..     ...   ...  ..  ..  ..   ...
# 62      63  10.0  17   2   9   8.0
# 63      64  10.0  17   8   5   9.0
# 64      65   4.0  15   3   4   1.0
# 65      66   1.0   2   2  AB   NaN
# 66      67  10.0  14   7  18   NaN
#
# [67 rows x 6 columns]

# %%
new_data.dtypes
# Out:
# Sr. no.     object
# DM         float64
# FDS         object
# OOP         object
# CG          object
# DELD       float64
# dtype: object

# %%
new_data = new_data.apply(pd.to_numeric, errors='coerce')
new_data.dtypes
# Out:
# Sr. no.      int64
# DM         float64
# FDS        float64
# OOP        float64
# CG         float64
# DELD       float64
# dtype: object

# %%
print(new_data.corr())
# Out:
#           Sr. no.        DM       FDS       OOP        CG      DELD
# Sr. no.  1.000000 -0.550767 -0.208831 -0.246017 -0.334881 -0.274436
# DM      -0.550767  1.000000  0.435641  0.714500  0.578014  0.705329
# FDS     -0.208831  0.435641  1.000000  0.517194  0.619857  0.497201
# OOP     -0.246017  0.714500  0.517194  1.000000  0.574492  0.791644
# CG      -0.334881  0.578014  0.619857  0.574492  1.000000  0.638673
# DELD    -0.274436  0.705329  0.497201  0.791644  0.638673  1.000000

# %%
new_data.describe()
# Out:
#          Sr. no.         DM        FDS        OOP         CG       DELD
# count  67.000000  64.000000  65.000000  61.000000  63.000000  44.000000
# mean   34.000000  15.984375  17.461538  11.409836  13.507937  11.840909
# std    19.485037   6.373288   5.595972   6.981827   7.118520   6.853765
# min     1.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    17.500000  12.000000  14.000000   5.000000   8.000000   6.750000
# 50%    34.000000  18.000000  18.000000  11.000000  13.000000  10.000000
# 75%    50.500000  21.250000  22.000000  17.000000  18.000000  17.250000
# max    67.000000  24.000000  27.000000  25.000000  29.000000  27.000000

# %%
import matplotlib.pyplot as plt
data= data.iloc[:67]
dm = data.filter(items=['DM'])

# %%
dm
# Out:
#       DM
# 0   24.0
# 1   16.0
# 2   20.0
# 3   18.0
# 4   20.0
# ..   ...
# 62  10.0
# 63  10.0
# 64   4.0
# 65   1.0
# 66  10.0
#
# [67 rows x 1 columns]

# %%
data= data.iloc[:67]
dm = data.filter(items=['DM'])
dm['DM'] = pd.to_numeric(dm['DM'], errors='coerce')
dm= dm.dropna()
plt.figure(figsize=(8,6))
plt.boxplot(dm['DM'])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(dm['DM'],bins=5)
plt.show()

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
iris_df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
iris_df.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
from sklearn import preprocessing
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
min_max_scaler = preprocessing.MinMaxScaler()
x=iris_df.iloc[:,:4]
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df_normalized
# Out:
#             0         1         2         3
# 0    0.222222  0.625000  0.067797  0.041667
# 1    0.166667  0.416667  0.067797  0.041667
# 2    0.111111  0.500000  0.050847  0.041667
# 3    0.083333  0.458333  0.084746  0.041667
# 4    0.194444  0.666667  0.067797  0.041667
# ..        ...       ...       ...       ...
# 145  0.666667  0.416667  0.711864  0.916667
# 146  0.555556  0.208333  0.677966  0.750000
# 147  0.611111  0.416667  0.711864  0.791667
# 148  0.527778  0.583333  0.745763  0.916667
# 149  0.444444  0.416667  0.694915  0.708333
#
# [150 rows x 4 columns]
